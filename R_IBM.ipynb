# %% [markdown]
# **IMPORT ALL NECESSARY MODULES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **LOAD THE DATA**

# %%
store_df=pd.read_csv("/content/Sample - Superstore.csv",encoding='Windows-1252')
store_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
store_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
store_df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# **UNDERSTAND THE DATA**

# %%
store_df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
store_df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
store_df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
#number of products in each sub category
store_df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
#number of unique values in each column
store_df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
store_df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
store_df.corr()
# Out:
# <ipython-input-68-247dd0f53f84>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   store_df.corr()
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
store_df.cov()
# Out:
# <ipython-input-69-8863e593a657>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   store_df.cov()
#                    Row ID   Postal Code          Sales    Quantity  \
# Row ID       8.324169e+06  8.946577e+05   -2442.819776  -25.782598
# Postal Code  8.946577e+05  1.028080e+09 -476682.766590  910.415885
# Sales       -2.442820e+03 -4.766828e+05  388434.455308  278.459923
# Quantity    -2.578260e+01  9.104159e+02     278.459923    4.951113
# Discount     8.029358e+00  3.868704e+02      -3.627228    0.003961
# Profit       8.446585e+03 -2.250458e+05   69944.096586   34.534769
#
#                Discount         Profit
# Row ID         8.029358    8446.585421
# Postal Code  386.870404 -225045.849445
# Sales         -3.627228   69944.096586
# Quantity       0.003961      34.534769
# ...

# %%
store_df.duplicated().sum()
# Out:
# 0

# %%
store_df.drop_duplicates()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
store_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
store_df.dropna(inplace=True)

# %%
store_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# **ANALYZING DATA**

# %%
#total number of products in all categories
store_df['Category'].value_counts().sum()
# Out:
# 9994

# %%
#total sales of each subcategory
store_df.groupby('Sub-Category')['Sales'].sum()
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
store_df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
store_df.groupby('Sub-Category')['Profit'].mean()
# Out:
# Sub-Category
# Accessories     54.111788
# Appliances      38.922758
# Art              8.200737
# Binders         19.843574
# Bookcases      -15.230509
# Chairs          43.095894
# Copiers        817.909190
# Envelopes       27.418019
# Fasteners        4.375660
# Furnishings     13.645918
# Labels          15.236962
# Machines        29.432669
# Paper           24.856620
# Phones          50.073938
# Storage         25.152277
# Supplies        -6.258418
# Tables         -55.565771
# Name: Profit, dtype: float64

# %%
store_df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Furniture           8.699327
# Office Supplies    20.327050
# Technology         78.752002
# Name: Profit, dtype: float64

# %%
store_df.groupby('Product Name')['Profit'].mean()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                    3.462667
# #10 Gummed Flap White Envelopes, 100/Box                                                                4.191950
# #10 Self-Seal White Envelopes                                                                          13.030750
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                             31.877257
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                11.528060
#                                                                                                          ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4    23.128800
# iOttie HLCRIO102 Car Mount                                                                             -2.398800
# ...

# %% [markdown]
# **DATA VISUALIZATION**

# %%
store_df.groupby("City")["Sales"].sum().plot.line()
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# **COUNT PLOT OF STATE**

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=store_df['State'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the countplot, West Virginia has least count

# %% [markdown]
# **PROFIT AND SALES REGION-WISE**

# %%
store_df.groupby('Region')['Profit','Sales'].agg(['sum']).plot.bar()
plt.title("Total Profit and Sales per Region")
plt.show()
# Out:
# <ipython-input-83-73163493c142>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   store_df.groupby('Region')['Profit','Sales'].agg(['sum']).plot.bar()

# %% [markdown]
# Profit is less in Central region

# %% [markdown]
# **COUNT PLOT OF SUB CATEGORY**

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=store_df['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Copiers has the least count compared to all sub-categories

# %% [markdown]
# **COUNT PLOT OF REGION**

# %%
sns.countplot(x=store_df['Region'])
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %% [markdown]
# **LINE PLOT OF DISCOUNT VS PROFIT**

# %%
plt.figure(figsize=(10,4))
sns.lineplot(x='Discount',y='Profit',data=store_df,color='r',label='Discount')
plt.legend()

# %% [markdown]
# When discount is 0.5 the profit decreases

# %%
store_df['Quantity'].hist(bins=50,figsize=(15,8))
# Out:
# <Axes: >

# %% [markdown]
# **TOTAL PROFIT PER SEGMENT**

# %%
plt.figure(figsize=(12,3))
plt.barh(store_df['Segment'],store_df['Profit'],
        color = 'g',
        alpha = 1,
       height=0.5)

plt.title('Total Profit Per Segment',fontdict={'fontsize':15})
plt.ylabel('Profit')
plt.xlabel('Segment')
plt.show()

# %% [markdown]
# From the above graphs, it is realized that the consumer segment is doing positively well in terms of profit and discounted sales and the Home Office segment is the least performing in terms of discounted sales and profit

# %% [markdown]
# **BEST SELLING AND MOST PROFITABLE CATEGORY**

# %%
df = pd.DataFrame(store_df.groupby(['Category'])[['Discount', 'Profit', 'Quantity']].mean())
df
# Out:
#                  Discount     Profit  Quantity
# Category
# Furniture        0.173923   8.699327  3.785007
# Office Supplies  0.157285  20.327050  3.801195
# Technology       0.132323  78.752002  3.756903

# %%
sns.set_theme(style="whitegrid")
figure, axis = plt.subplots(1, 3, figsize=(12, 6))
# Plot barplots
cat1 = sns.barplot(x = df.index, y = df.Discount, ax=axis[0], palette = "Greens")
cat2 = sns.barplot(x = df.index, y = df.Profit, ax=axis[1], palette = "Greens")
cat3 = sns.barplot(x = df.index, y = df.Quantity, ax=axis[2], palette = "Greens")
# Set titles
cat1.set(title = 'Discount')
cat2.set(title = 'Profit')
cat3.set(title = 'Quantity')
# Rotate axis for x-axis
plt.setp(cat1.get_xticklabels(), rotation = 'horizontal', size = 9)
plt.setp(cat2.get_xticklabels(), rotation = 'horizontal', size = 9)
plt.setp(cat3.get_xticklabels(), rotation = 'horizontal', size = 9)
# Set spacing between subplots
figure.tight_layout()

# %% [markdown]
# Here, we can see that all though the quantities of all the Categories are close to same as per the grapgh on the far right, it is shown that the Technology category has the highest sale, and equally brings in the most sales to the superstore.
#
# Next off, we see that the Furnture category is the second best selling category after the Technology category but brings in the least profits.
#
# Lastly, the least selling category shown as the Office Supplies, is the category bringing in the second best categoory performing in terms of profit.

# %% [markdown]
# **TOP TEN BEST PERFORMING CITIES**

# %%
city_sales_df = pd.DataFrame(store_df.groupby(['City'])['Discount','Quantity','Profit'].mean().
                             sort_values('Discount',ascending = False))
top10 = city_sales_df[:10]
top10
# Out:
# <ipython-input-92-762fc7db789d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   city_sales_df = pd.DataFrame(store_df.groupby(['City'])['Discount','Quantity','Profit'].mean().
#                Discount  Quantity    Profit
# City
# Missouri City  0.800000       7.0  -9.55500
# Romeoville     0.800000       2.0 -14.77080
# Deer Park      0.800000       6.0 -10.38600
# Abilene        0.800000       2.0  -3.75840
# Elyria         0.700000       1.0  -1.39840
# Littleton      0.700000       1.0 -98.80180
# Ormond Beach   0.700000       3.0  -1.96560
# Pensacola      0.700000       3.0  -1.47600
# Tyler          0.640000       3.2 -88.74172
# Bryan          0.616667       4.5 -35.61860

# %% [markdown]
# **COUNT OF CATEGORY REGION-WISE**

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="Category", hue="Region", data=store_df)
plt.show()

# %% [markdown]
# People residing in Western part of US tend to order more from superstore.

# %% [markdown]
# **MONEY LOSS**

# %%
loss_df = store_df[store_df['Profit'] < 0]
Total_loss=np.negative(loss_df['Profit'].sum())
print("Total loss = %.2f" %Total_loss)
# Out:
# Total loss = 156131.29

# %% [markdown]
# **CUSTOMER REGIONAL ANALYSIS**

# %%
region_analysis = pd.DataFrame(store_df.groupby(['Region'])['Profit'].sum().reset_index())
region_analysis
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 1     East   91522.7800
# 2    South   46749.4303
# 3     West  108418.4489

# %% [markdown]
# **WHICH REGION IS THE MOST PROFITABLE?**

# %%
plt.pie(region_analysis.Profit,
        labels = region_analysis.Region,
        startangle = 90, autopct = "%1.0f%%",
        explode = [0, 0, 0, 0.1])
plt.title("Most Profitable by Region")
plt.show()

# %% [markdown]
# West Region is the most profitable

# %% [markdown]
# **BAR PLOT OF SUBCATEGORY AND CATEGORY**

# %%
plt.figure(figsize=(16,8))
plt.bar( "Sub-Category","Category", data=store_df)
plt.show()

# %% [markdown]
# In furniture category the frequency of individual item is less
# In office supplies category the frequency of individual item is less
# In technology category the frequency of individual item is high
